# %% [markdown]
# <a href="https://colab.research.google.com/github/programmermahi/Machine-Learning-Lab/blob/main/sns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# ডেটা লোড
tips = sns.load_dataset("tips")

# স্টাইল সেট
sns.set_style("whitegrid")

# Figure তৈরি
plt.figure(figsize=(10,10))

# Scatter plot with hue
sns.scatterplot(
    x='total_bill',
    y='tip',
    data=tips,
    hue='time',  # ভিন্ন রং
    style='smoker',  # ভিন্ন marker
    size='size'  # ভিন্ন size
)

# Title এবং labels
plt.title("Total Bill vs Tip Amount")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")

# Show plot
plt.show()
