# %% [markdown]
# <a href="https://colab.research.google.com/github/programmermahi/Machine-Learning-Lab/blob/main/LinerDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
dataset = pd.read_csv('/content/student_scores.csv')
dataset.head()
dataset
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
dataset.plot(x='Hours', y='Scores', style='*', color='g')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()
dataset.shape
# Out:
# (25, 2)

# %%
X = dataset.iloc[:, :-1]. values
y = dataset.iloc[:, 1]. values

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X, y, test_size =0.2, random_state =0)
X_train
y_train
# Out:
# array([35, 24, 86, 76, 17, 47, 85, 42, 81, 88, 67, 30, 25, 60, 30, 75, 21,
#        54, 95, 41])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression ()
regressor.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 2.018160041434662
# [9.91065648]

# %%
y_pred = regressor.predict(X_test)
df = pd.DataFrame ({'Actual': y_test , 'Predicted': y_pred})
df.head(5)
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
# Out:
# Mean Squared Error: 21.598769307217456

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(y_test , y_pred))

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Rough Error = Mean Absolute Error (MAE)
mae = metrics.mean_absolute_error(y_test, y_pred)
print("Rough Error (Mean Absolute Error):", mae)
# Out:
# Mean Squared Error: 21.598769307217456
# Root Mean Squared Error (RMSE): 4.647447612100373
# Rough Error (Mean Absolute Error): 4.183859899002982

# %%
from sklearn import metrics
import numpy as np

# Calculate metrics
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = metrics.mean_absolute_error(y_test, y_pred)

# Print results as full sentences
print(f"The Mean Squared Error (MSE) between the actual and predicted values is: {mse:.2f}")
print(f"The Root Mean Squared Error (RMSE) is: {rmse:.2f}, which gives an idea of the average prediction error in the same units as the target variable.")
print(f"The Rough Error, also known as Mean Absolute Error (MAE), is: {mae:.2f}, representing the average absolute difference between predictions and actual values.")
# Out:
# The Mean Squared Error (MSE) between the actual and predicted values is: 21.60
# The Root Mean Squared Error (RMSE) is: 4.65, which gives an idea of the average prediction error in the same units as the target variable.
# The Rough Error, also known as Mean Absolute Error (MAE), is: 4.18, representing the average absolute difference between predictions and actual values.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics

# Example data — replace with your real y_test and y_pred
# y_test = [actual values], y_pred = [predicted values]

# Calculate errors
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = metrics.mean_absolute_error(y_test, y_pred)

# Print metrics in sentences
print(f"The Mean Squared Error (MSE) between the actual and predicted values is: {mse:.2f}")
print(f"The Root Mean Squared Error (RMSE) is: {rmse:.2f}, which gives an idea of the average prediction error in the same units as the target variable.")
print(f"The Rough Error, also known as Mean Absolute Error (MAE), is: {mae:.2f}, representing the average absolute difference between predictions and actual values.")

# Create figure and subplots
plt.figure(figsize=(14, 6))

# Plot 1: Actual vs Predicted values
plt.subplot(1, 2, 1)
plt.plot(y_test, label='Actual', marker='o')
plt.plot(y_pred, label='Predicted', marker='x')
plt.title('Actual vs Predicted Values')
plt.xlabel('Sample Index')
plt.ylabel('Target Value')
plt.legend()
plt.grid(True)

# Plot 2: Error (Difference between Actual and Predicted)
errors = np.array(y_test) - np.array(y_pred)
plt.subplot(1, 2, 2)
plt.plot(errors, color='red', marker='d', label='Error')
plt.axhline(0, color='black', linestyle='--')
plt.title('Prediction Errors (Actual - Predicted)')
plt.xlabel('Sample Index')
plt.ylabel('Error Value')
plt.legend()
plt.grid(True)

# Show plots
plt.tight_layout()
plt.show()
# Out:
# The Mean Squared Error (MSE) between the actual and predicted values is: 21.60
# The Root Mean Squared Error (RMSE) is: 4.65, which gives an idea of the average prediction error in the same units as the target variable.
# The Rough Error, also known as Mean Absolute Error (MAE), is: 4.18, representing the average absolute difference between predictions and actual values.
